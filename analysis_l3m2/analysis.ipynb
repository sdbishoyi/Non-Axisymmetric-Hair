% %% [markdown]
% # Analysis of l=3,m=2 non-axisymmetric mode

% %% [markdown]
% We are only working with $l=3,m=2$ mode in the calculations below. The field and its derivative have been calculated on the horizon.
%
% bbscalar -> beetle-burko scalar
% infield -> $\psi_{0}$
% outfield -> $\psi_{4}$

% %% [markdown]
% # Gaussian with center 1.0

% %%
addpath('phd_work/projects/non_axisymmetric_hair/data_l3m2/loc10')
infield_data = load('Psi0_TimeDAT_0.dat');
der_infield_data = load('Psi0_TimeDAT_1.dat');
outfield_data = load('Psi4_TimeDAT_0.dat');
der_outfield_data = load('Psi4_TimeDAT_1.dat');

time_infield_10 = infield_data(:,1);
real_infield = infield_data(:,4);
imag_infield = infield_data(:,5);
real_der_infield = der_infield_data(:,4);
imag_der_infield = der_infield_data(:,5);

time_outfield = outfield_data(:,1);
real_outfield = outfield_data(:,4);
imag_outfield = outfield_data(:,5);
real_der_outfield = der_outfield_data(:,4);
imag_der_outfield = der_outfield_data(:,5);

rmpath('phd_work/projects/non_axisymmetric_hair/data_l3m2/loc10')

% %%
Psi0 = real_infield + 1i.*imag_infield;
Psi4 = real_outfield + 1i.*imag_outfield;

der_Psi0 = real_der_infield + 1i.*imag_der_infield;
der_Psi4 = real_der_outfield + 1i.*imag_der_outfield;
size(Psi0),size(Psi4)

bbscalar_10 = Psi0.*Psi4;
hair_10 = abs(Psi0.*der_Psi4 + Psi4.*der_Psi0);
der_hair_10 = (hair_10(2:end) - hair_10(1:end-1))./(time_infield_10(2:end) - time_infield_10(1:end-1));
% Out:
% ans = 1x2 double
%        58093           1
% ans = 1x2 double
%        58093           1

% %%
plot(log10(time_infield_10),log10(abs(bbscalar_10)))
hold on
plot(log10(time_infield_10(end-45647:end)),-1.0*log10(time_infield_10(end-45647:end))-0.55)
hold off
xlim([2,3.5])
ylim([-4,-1.5])
xlabel('log_{10}time')
ylabel('log_{10}|\psi_{0}\psi_{4}|')

% %%
plot(time_infield_10,hair_10)
ylim([-5,10])
xlabel('time')
ylabel('|\partial_{r}(\psi_{0}\psi_{4})|')

% %%
plot(log10(time_infield_10),log10(hair_10))
xlim([2,4])
%ylim([30,50])
xlabel('log_{10}time')
ylabel('log_{10}|\partial_{r}(\psi_{0}\psi_{4})|')

% %% [markdown]
% # Gaussian with center 1.1

% %% [markdown]
% ## Loading and extracting data

% %%
addpath('phd_work/projects/non_axisymmetric_hair/data_l3m2/loc11')
infield_data = load('Psi0_TimeDAT_0.dat');
der_infield_data = load('Psi0_TimeDAT_1.dat');
outfield_data = load('Psi4_TimeDAT_0.dat');
der_outfield_data = load('Psi4_TimeDAT_1.dat');

time_infield_11 = infield_data(:,1);
real_infield = infield_data(:,4);
imag_infield = infield_data(:,5);
real_der_infield = der_infield_data(:,4);
imag_der_infield = der_infield_data(:,5);

time_outfield = outfield_data(:,1);
real_outfield = outfield_data(:,4);
imag_outfield = outfield_data(:,5);
real_der_outfield = der_outfield_data(:,4);
imag_der_outfield = der_outfield_data(:,5);

rmpath('phd_work/projects/non_axisymmetric_hair/data_l3m2/loc11')

% %% [markdown]
% ## Defining fields and their derivatives

% %%
Psi0 = real_infield + 1i.*imag_infield;
Psi4 = real_outfield + 1i.*imag_outfield;

der_Psi0 = real_der_infield + 1i.*imag_der_infield;
der_Psi4 = real_der_outfield + 1i.*imag_der_outfield;
size(Psi0),size(Psi4)

bbscalar_11 = Psi0.*Psi4;
hair_11 = abs(Psi0.*der_Psi4 + Psi4.*der_Psi0);
der_hair_11 = (hair_11(2:end) - hair_11(1:end-1))./(time_infield_11(2:end) - time_infield_11(1:end-1));
% Out:
% ans = 1x2 double
%        58093           1
% ans = 1x2 double
%        58093           1

% %%
plot(log10(time_infield_11),log10(abs(bbscalar_11)))
hold on
plot(log10(time_infield_11(end-45647:end)),-1.0*log10(time_infield_11(end-45647:end))-0.25)
hold off
xlim([2,3.5])
ylim([-4,-2.5])
xlabel('log_{10}time')
ylabel('log_{10}|\psi_{0}\psi_{4}|')

% %%
plot(time_infield_11,hair_11)
ylim([-5,10])
xlabel('time')
ylabel('|\partial_{r}(\psi_{0}\psi_{4})|')

% %%
plot(log10(time_infield_11),log10(hair_11))
xlim([2,4])
%ylim([30,50])
xlabel('log_{10}time')
ylabel('log_{10}|\partial_{r}(\psi_{0}\psi_{4})|')

% %% [markdown]
% # Gaussian with center 1.2

% %%
addpath('phd_work/projects/non_axisymmetric_hair/data_l3m2/loc12')
infield_data = load('Psi0_TimeDAT_0.dat');
der_infield_data = load('Psi0_TimeDAT_1.dat');
outfield_data = load('Psi4_TimeDAT_0.dat');
der_outfield_data = load('Psi4_TimeDAT_1.dat');

time_infield_12 = infield_data(:,1);
real_infield = infield_data(:,4);
imag_infield = infield_data(:,5);
real_der_infield = der_infield_data(:,4);
imag_der_infield = der_infield_data(:,5);

time_outfield = outfield_data(:,1);
real_outfield = outfield_data(:,4);
imag_outfield = outfield_data(:,5);
real_der_outfield = der_outfield_data(:,4);
imag_der_outfield = der_outfield_data(:,5);

rmpath('phd_work/projects/non_axisymmetric_hair/data_l3m2/loc12')

% %%
Psi0 = real_infield + 1i.*imag_infield;
Psi4 = real_outfield + 1i.*imag_outfield;

der_Psi0 = real_der_infield + 1i.*imag_der_infield;
der_Psi4 = real_der_outfield + 1i.*imag_der_outfield;

bbscalar_12 = Psi0.*Psi4;
hair_12 = abs(Psi0.*der_Psi4 + Psi4.*der_Psi0);
der_hair_12 = (hair_12(2:end) - hair_12(1:end-1))./(time_infield_12(2:end) - time_infield_12(1:end-1));

% %%
plot(log10(time_infield_12),log10(abs(bbscalar_12)))
hold on
plot(log10(time_infield_12(end-45647:end)),-1.0*log10(time_infield_12(end-45647:end))-0.20)
hold off
xlim([1,3.5])
ylim([-4,-1.5])
xlabel('log_{10}time')
ylabel('log_{10}|\psi_{0}\psi_{4}|')

% %%
plot(time_infield_12,hair_12)
ylim([-5,10])
xlabel('time')
ylabel('|\partial_{r}(\psi_{0}\psi_{4})|')

% %%
plot(log10(time_infield_12),log10(hair_12))
xlim([2,4])
%ylim([30,50])
xlabel('log_{10}time')
ylabel('log_{10}|\partial_{r}(\psi_{0}\psi_{4})|')

% %% [markdown]
% # Gaussian with center 1.3

% %%
addpath('phd_work/projects/non_axisymmetric_hair/data_l3m2/loc13')
infield_data = load('Psi0_TimeDAT_0.dat');
der_infield_data = load('Psi0_TimeDAT_1.dat');
outfield_data = load('Psi4_TimeDAT_0.dat');
der_outfield_data = load('Psi4_TimeDAT_1.dat');

time_infield_13 = infield_data(1:51000,1);
real_infield = infield_data(1:51000,4);
imag_infield = infield_data(1:51000,5);
real_der_infield = der_infield_data(1:51000,4);
imag_der_infield = der_infield_data(1:51000,5);

time_outfield = outfield_data(1:51000,1);
real_outfield = outfield_data(1:51000,4);
imag_outfield = outfield_data(1:51000,5);
real_der_outfield = der_outfield_data(1:51000,4);
imag_der_outfield = der_outfield_data(1:51000,5);

rmpath('phd_work/projects/non_axisymmetric_hair/data_l3m2/loc13')

% %%
Psi0 = real_infield + 1i.*imag_infield;
Psi4 = real_outfield + 1i.*imag_outfield;

der_Psi0 = real_der_infield + 1i.*imag_der_infield;
der_Psi4 = real_der_outfield + 1i.*imag_der_outfield;

bbscalar_13 = Psi0.*Psi4;
hair_13 = abs(Psi0.*der_Psi4 + Psi4.*der_Psi0);
der_hair_13 = (hair_13(2:end) - hair_13(1:end-1))./(time_infield_13(2:end) - time_infield_13(1:end-1));

% %%
plot(log10(time_infield_13),log10(abs(bbscalar_13)))
hold on
plot(log10(time_infield_13(end-45647:end)),-1.3*log10(time_infield_13(end-45647:end))+0.5)
plot(log10(time_infield_13(end-45647:end)),-1.0*log10(time_infield_13(end-45647:end))-0.25)
hold off
xlim([2,3.5])
ylim([-4,-2.0])
xlabel('log_{10}time')
ylabel('log_{10}|\psi_{0}\psi_{4}|')

% %%
plot(time_infield_13,hair_13)
ylim([-5,10])
xlabel('time')
ylabel('|\partial_{r}(\psi_{0}\psi_{4})|')

% %%
plot(log10(time_infield_13),log10(hair_13))
xlim([2,4])
%ylim([30,50])
xlabel('log_{10}time')
ylabel('log_{10}|\partial_{r}(\psi_{0}\psi_{4})|')

% %%
plot(log10(time_infield_13),log10(abs(Psi0)))
hold on
plot(log10(time_infield_13),-2.5*log10(time_infield_13))
plot(log10(time_infield_13),-2.8*log10(time_infield_13)+0.25)
plot(log10(time_infield_13),log10(abs(Psi4)))
plot(log10(time_infield_13),1.5*log10(time_infield_13))
hold off
xlim([2,3.5])

% %% [markdown]
% # Gaussian with center 1.4

% %%
addpath('phd_work/projects/non_axisymmetric_hair/data_l3m2/loc14')
infield_data = load('Psi0_TimeDAT_0.dat');
der_infield_data = load('Psi0_TimeDAT_1.dat');
outfield_data = load('Psi4_TimeDAT_0.dat');
der_outfield_data = load('Psi4_TimeDAT_1.dat');

time_infield_14 = infield_data(1:51000,1);
real_infield = infield_data(1:51000,4);
imag_infield = infield_data(1:51000,5);
real_der_infield = der_infield_data(1:51000,4);
imag_der_infield = der_infield_data(1:51000,5);

time_outfield = outfield_data(1:51000,1);
real_outfield = outfield_data(1:51000,4);
imag_outfield = outfield_data(1:51000,5);
real_der_outfield = der_outfield_data(1:51000,4);
imag_der_outfield = der_outfield_data(1:51000,5);

rmpath('phd_work/projects/non_axisymmetric_hair/data_l3m2/loc14')

% %%
Psi0 = real_infield + 1i.*imag_infield;
Psi4 = real_outfield + 1i.*imag_outfield;

der_Psi0 = real_der_infield + 1i.*imag_der_infield;
der_Psi4 = real_der_outfield + 1i.*imag_der_outfield;

bbscalar_14 = Psi0.*Psi4;
hair_14 = abs(Psi0.*der_Psi4 + Psi4.*der_Psi0);
der_hair_14 = (hair_14(2:end) - hair_14(1:end-1))./(time_infield_14(2:end) - time_infield_14(1:end-1));

% %%
plot(time_infield_14(2:end),der_hair_14)
hold on
plot(time_infield_13(2:end),der_hair_13)
hold off
ylim([-0.01,0.01])

% %%
plot(log10(time_infield_14),log10(abs(bbscalar_14)))
hold on
plot(log10(time_infield_14(end-45647:end)),-1.5*log10(time_infield_14(end-45647:end))+1.0)
hold off
xlim([1,3.5])
ylim([-4,-1.5])
xlabel('log_{10}time')
ylabel('log_{10}|\psi_{0}\psi_{4}|')

% %%
plot(time_infield_14,hair_14)
ylim([-5,10])
xlabel('time')
ylabel('|\partial_{r}(\psi_{0}\psi_{4})|')

% %%
plot(log10(time_infield_14),log10(hair_14))
hold on
plot(log10(time_infield_14),-0.5*log10(time_infield_14)+0.25)
hold off
xlim([2,4])
%ylim([30,50])
xlabel('log_{10}time')
ylabel('log_{10}|\partial_{r}(\psi_{0}\psi_{4})|')

% %%
plot(log10(time_infield_14),log10(abs(Psi0)))
hold on
plot(log10(time_infield_14),-2.5*log10(time_infield_14))
%plot(log10(time_infield_14),-3.0*log10(time_infield_14)+1.25)
plot(log10(time_infield_14),log10(abs(Psi4)))
plot(log10(time_infield_14),1.5*log10(time_infield_14))
hold off
xlim([2,3.5])
legend()
filename = fullfile('phd_work/projects/non_axisymmetric_hair/plots_l3m2', 'logpsi0vslogtime_14.pdf');
saveas(gcf,filename);

% %%
plot(log10(time_infield_14),log10(abs(der_Psi0)))
hold on
plot(log10(time_infield_14),-1.5*log10(time_infield_14))
%plot(log10(time_infield_14),-2.0*log10(time_infield_14)+1.25)
plot(log10(time_infield_14),log10(abs(der_Psi4)))
plot(log10(time_infield_14),2.5*log10(time_infield_14))
hold off
xlim([2,3.5])
legend()
filename = fullfile('phd_work/projects/non_axisymmetric_hair/plots_l3m2', 'logderpsi0vslogtime_14.pdf');
saveas(gcf,filename);

% %%
plot(time_infield_10(1:51000),hair_10(1:51000))
hold on
plot(time_infield_11(1:51000),hair_11(1:51000))
plot(time_infield_12(1:51000),hair_12(1:51000))
plot(time_infield_13,hair_13)
plot(time_infield_14,hair_14)
%plot(time_infield_14,ones(size(hair_14)))
hold off
xlim([400,2000])
ylim([-1,5])
xlabel('time')
ylabel('|\partial_{r}(\psi_{0}\psi_{4})|')
legend('1.0','1.1','1.2','1.3','1.4')

% %%
plot(log10(time_infield_10(1:51000)),log10(abs(bbscalar_10(1:51000))))
hold on
plot(log10(time_infield_11(1:51000)),log10(abs(bbscalar_11(1:51000))))
plot(log10(time_infield_12(1:51000)),log10(abs(bbscalar_12(1:51000))))
plot(log10(time_infield_12(1:51000)),-1.0*log10(time_infield_12(1:51000))-0.5)
%plot(log10(time_infield_13),log10(abs(bbscalar_13)))
%plot(log10(time_infield_14),log10(abs(bbscalar_14)))
hold off
xlim([2,3.5])
ylim([-4,-1])
xlabel('time')
ylabel('|\partial_{r}(\psi_{0}\psi_{4})|')
legend('1.0','1.1','1.2','1.3','1.4')

% %%
plot(log10(time_infield_13),log10(abs(bbscalar_13)))
hold on
plot(log10(time_infield_13),-1.3*log10(time_infield_13)+0.75)
plot(log10(time_infield_14),log10(abs(bbscalar_14)))
plot(log10(time_infield_14),-1.5*log10(time_infield_14)+1.0)
hold off
xlim([2,3.5])
ylim([-4,-1])
xlabel('time')
ylabel('|\partial_{r}(\psi_{0}\psi_{4})|')
legend()
